# %%
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
plt.plot([1, 2, 3, 10])

# %%
print(True)
# prin
# Out:
# True

# %%
a = True
a
# print(a)
# Out:
# True

# %%
def f():
  return True

def g():
  print(True)

# %%
if f():
  print('f() is True')
if g():
  print('g() is True')
# Out:
# f() is True
# True
